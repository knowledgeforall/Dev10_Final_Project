# %%
# Mount the District container
storageAccount = "gen10datafund2205"
storageContainer = "capstone-group3-lassomodelpowerbi"
clientSecret = "-ZS8Q~NwOKfwEpVOg3Teb1pPtxDbz616XjlXLbuU"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/capstone-group3-lassomodelpowerbi"
    
    
configs = {"fs.azure.account.auth.type": "OAuth",
   "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
   "fs.azure.account.oauth2.client.id": clientid,
   "fs.azure.account.oauth2.client.secret": clientSecret,
   "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
   "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try:
    dbutils.fs.unmount(mount_point)
except:
    pass


dbutils.fs.mount(
source = f"abfss://{storageContainer}@{storageAccount}.dfs.core.windows.net/", 
mount_point = mount_point, 
extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/capstone-group3-lassomodelpowerbi has been unmounted.
# Out[18]: True</div>

# %%
# %fs
ls /mnt/capstone-group3-lassomodelpowerbi/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/capstone-group3-lassomodelpowerbi/AltMLModelDatasetPowerBI.csv</td><td>AltMLModelDatasetPowerBI.csv</td><td>36092</td><td>1660673631000</td></tr><tr><td>dbfs:/mnt/capstone-group3-lassomodelpowerbi/MLModelDatasetPowerBI.csv</td><td>MLModelDatasetPowerBI.csv</td><td>30047</td><td>1660660947000</td></tr><tr><td>dbfs:/mnt/capstone-group3-lassomodelpowerbi/MLModelDatasetPowerBI2.csv</td><td>MLModelDatasetPowerBI2.csv</td><td>30047</td><td>1660660955000</td></tr></tbody></table></div>

# %%
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# df = pd.read_csv('/dbfs/mnt/capstone-group3-lassomodelpowerbi/AltMLModelDatasetPowerBI.csv')
2
df = spark.read.option("header",True).csv('dbfs:/mnt/capstone-group3-lassomodelpowerbi/AltMLModelDatasetPowerBI.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = df.drop('_c0')
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: [(&#39;GraduationPercentageRate&#39;, &#39;string&#39;),
#  (&#39;HouseholdIncome&#39;, &#39;string&#39;),
#  (&#39;FundingPerStudent&#39;, &#39;string&#39;),
#  (&#39;DropoutPercentageRate&#39;, &#39;string&#39;),
#  (&#39;Percentage of Minority Students&#39;, &#39;string&#39;),
#  (&#39;DistrictName&#39;, &#39;string&#39;)]</div>

# %%
from pyspark.sql.types import DecimalType, StringType, FloatType

output_df = df \
  .withColumn("GraduationPercentageRate", df["GraduationPercentageRate"].cast(FloatType())) \
  .withColumn("DropoutPercentageRate", df["DropoutPercentageRate"].cast(FloatType())) \
  .withColumn("FundingPerStudent", df["FundingPerStudent"].cast(FloatType())) \
  .withColumn("HouseholdIncome", df["HouseholdIncome"].cast(FloatType())) \
  .withColumn("Percentage of Minority Students", df["Percentage of Minority Students"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
database = "Capstone-Group3"
table = "dbo.nystatedistricts3"
user = "stanleyperez"
password  = "Ezra!1223"
server = "gen10-data-fundamentals-22-05-sql-server.database.windows.net"

output_df.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .mode("overwrite") \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# df = pd.read_csv('/dbfs/mnt/capstone-group3-lassomodelpowerbi/districtdatafinal.csv')
2
df = spark.read.option("header",True).csv('dbfs:/mnt/capstone-group3-lassomodelpowerbi/AltMLModelDatasetPowerBI.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = df.drop('_c0')
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: [(&#39;GraduationPercentageRate&#39;, &#39;string&#39;),
#  (&#39;HouseholdIncome&#39;, &#39;string&#39;),
#  (&#39;FundingPerStudent&#39;, &#39;string&#39;),
#  (&#39;DropoutPercentageRate&#39;, &#39;string&#39;),
#  (&#39;Percentage of Minority Students&#39;, &#39;string&#39;),
#  (&#39;DistrictName&#39;, &#39;string&#39;)]</div>

# %%
from pyspark.sql.types import DecimalType, StringType, FloatType

output_df = df \
  .withColumn("GraduationPercentageRate", df["GraduationPercentageRate"].cast(FloatType())) \
  .withColumn("DropoutPercentageRate", df["DropoutPercentageRate"].cast(FloatType())) \
  .withColumn("FundingPerStudent", df["FundingPerStudent"].cast(FloatType())) \
  .withColumn("HouseholdIncome", df["HouseholdIncome"].cast(FloatType())) \
  .withColumn("Percentage of Minority Students", df["Percentage of Minority Students"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
database = "Capstone-Group3"
table = "dbo.nystatedistricts2"
user = "stanleyperez"
password  = "Ezra!1223"
server = "gen10-data-fundamentals-22-05-sql-server.database.windows.net"

output_df.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .mode("overwrite") \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# df = pd.read_csv('/dbfs/mnt/capstone-group3-lassomodelpowerbi/MLModelDatasetPowerBI.csv')
df = spark.read.option("header",True).csv('dbfs:/mnt/capstone-group3-lassomodelpowerbi/MLModelDatasetPowerBI.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = df.drop('_c0')
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: [(&#39;GraduationPercentageRate&#39;, &#39;string&#39;),
#  (&#39;HouseholdIncome&#39;, &#39;string&#39;),
#  (&#39;FundingPerStudent&#39;, &#39;string&#39;),
#  (&#39;DropoutPercentageRate&#39;, &#39;string&#39;),
#  (&#39;Percentage of Minority Students&#39;, &#39;string&#39;),
#  (&#39;DistrictName&#39;, &#39;string&#39;)]</div>

# %%
from pyspark.sql.types import DecimalType, StringType, FloatType

output_df = df \
  .withColumn("GraduationPercentageRate", df["GraduationPercentageRate"].cast(FloatType())) \
  .withColumn("DropoutPercentageRate", df["DropoutPercentageRate"].cast(FloatType())) \
  .withColumn("FundingPerStudent", df["FundingPerStudent"].cast(FloatType())) \
  .withColumn("HouseholdIncome", df["HouseholdIncome"].cast(FloatType())) \
  .withColumn("Percentage of Minority Students", df["Percentage of Minority Students"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
database = "Capstone-Group3"
table = "dbo.MLMODEL"
user = "stanleyperez"
password  = "Ezra!1223"
server = "gen10-data-fundamentals-22-05-sql-server.database.windows.net"

output_df.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .mode("overwrite") \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# df = pd.read_csv('/dbfs/mnt/capstone-group3-lassomodelpowerbi/MLModelDatasetPowerBI2.csv')
df = spark.read.option("header",True).csv('dbfs:/mnt/capstone-group3-lassomodelpowerbi/MLModelDatasetPowerBI2.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = df.drop('_c0')
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: [(&#39;GraduationPercentageRate&#39;, &#39;string&#39;),
#  (&#39;HouseholdIncome&#39;, &#39;string&#39;),
#  (&#39;FundingPerStudent&#39;, &#39;string&#39;),
#  (&#39;DropoutPercentageRate&#39;, &#39;string&#39;),
#  (&#39;Percentage of Minority Students&#39;, &#39;string&#39;),
#  (&#39;DistrictName&#39;, &#39;string&#39;)]</div>

# %%
from pyspark.sql.types import DecimalType, StringType, FloatType

output_df = df \
  .withColumn("GraduationPercentageRate", df["GraduationPercentageRate"].cast(FloatType())) \
  .withColumn("DropoutPercentageRate", df["DropoutPercentageRate"].cast(FloatType())) \
  .withColumn("FundingPerStudent", df["FundingPerStudent"].cast(FloatType())) \
  .withColumn("HouseholdIncome", df["HouseholdIncome"].cast(FloatType())) \
  .withColumn("Percentage of Minority Students", df["Percentage of Minority Students"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
database = "Capstone-Group3"
table = "dbo.MLMODEL2"
user = "stanleyperez"
password  = "Ezra!1223"
server = "gen10-data-fundamentals-22-05-sql-server.database.windows.net"

output_df.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .mode("overwrite") \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
