# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('districtdatafinal.csv')

# %%
df = df[['GraduationPercentageRate','DropoutPercentageRate','FundingPerStudent','TotalEnrolled', 'Percentage of Minority Students','HouseholdIncome']]

# %%
df.corr()
# Out:
#                                  GraduationPercentageRate  \
# GraduationPercentageRate                         1.000000
# DropoutPercentageRate                           -0.789692
# FundingPerStudent                               -0.026112
# TotalEnrolled                                   -0.212696
# Percentage of Minority Students                 -0.359994
# HouseholdIncome                                  0.344243
#
#                                  DropoutPercentageRate  FundingPerStudent  \
# GraduationPercentageRate                     -0.789692          -0.026112
# DropoutPercentageRate                         1.000000          -0.065178
# FundingPerStudent                            -0.065178           1.000000
# TotalEnrolled                                 0.053425          -0.163294
# Percentage of Minority Students               0.172194           0.119716
# HouseholdIncome                              -0.367961           0.230662
#
# ...

# %%
correlation = df.corr()

# %%
sns.heatmap(correlation, annot = True)
plt.show()
