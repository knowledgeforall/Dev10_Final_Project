# %%
import pandas as pd
import numpy as np
# from sklearn.impute import SimpleImputer

# %%
# Storing the file path in 'loc' variable
loc = (r"C:\Users\Minet\Documents\Repositories\Dev10_Final_Project\Datasets\nystate.csv")
# Importing the file from the file path contained in 'loc' into 'df' 
df = pd.read_csv(loc)
# Showing the first 5 rows of 'df'
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                 DistrictName  \
# 0             0           0                  ADDISON CSD
# 1             1           1               ADIRONDACK CSD
# 2             2           2                    AFTON CSD
# 3             3           3                    AKRON CSD
# 4             4           4  ALBANY CITY SCHOOL DISTRICT
#
#   GraduationPercentageRate DropoutPercentageRate  FundingPerStudent  \
# 0                       90                     3           23833.02
# 1                       92                     5           14013.61
# 2                       83                    10           24128.02
# 3                       95                     3           17552.56
# 4                       71                    12           22382.65
#
#    TotalEnrolled  MalesEnrolled  FemalesEnrolled  \
# 0            976            503              473
# 1           1145            575              570
# 2            507            262              245
# ...

# %%
# create new dataframe
df = df[['GraduationPercentageRate','GraduationPercentageRate','HouseholdIncome','FundingPerStudent', 'DropoutPercentageRate', 'Percentage of Minority Students']]
df.head()
# Out:
#   GraduationPercentageRate GraduationPercentageRate  HouseholdIncome  \
# 0                       90                       90          59328.0
# 1                       92                       92          63986.4
# 2                       83                       83          54818.3
# 3                       95                       95          76903.8
# 4                       71                       71          61049.2
#
#    FundingPerStudent DropoutPercentageRate  Percentage of Minority Students
# 0           23833.02                     3                              3.2
# 1           14013.61                     5                              1.7
# 2           24128.02                    10                              8.9
# 3           17552.56                     3                             17.5
# 4           22382.65                    12                             80.2

# %%
df.columns=['GraduationPercentageRate', 'OrgininalGraduationPercentageRate','HouseholdIncome','FundingPerStudent', 'DropoutPercentageRate', 'Percentage of Minority Students']
df.head()
# Out:
#   GraduationPercentageRate OrgininalGraduationPercentageRate  HouseholdIncome  \
# 0                       90                                90          59328.0
# 1                       92                                92          63986.4
# 2                       83                                83          54818.3
# 3                       95                                95          76903.8
# 4                       71                                71          61049.2
#
#    FundingPerStudent DropoutPercentageRate  Percentage of Minority Students
# 0           23833.02                     3                              3.2
# 1           14013.61                     5                              1.7
# 2           24128.02                    10                              8.9
# 3           17552.56                     3                             17.5
# 4           22382.65                    12                             80.2

# %%
df = df[df.DropoutPercentageRate != '—']
df = df[df.GraduationPercentageRate != '—']
# df.head(13)

# %%
print(df.isnull().sum())
# Out:
# GraduationPercentageRate              0
# OrgininalGraduationPercentageRate     0
# HouseholdIncome                      32
# FundingPerStudent                    38
# DropoutPercentageRate                 0
# Percentage of Minority Students       0
# dtype: int64

# %%
df = df.dropna()
df.head(13)
# Out:
#    GraduationPercentageRate OrgininalGraduationPercentageRate  \
# 0                        90                                90
# 1                        92                                92
# 2                        83                                83
# 3                        95                                95
# 4                        71                                71
# 5                        85                                85
# 6                        96                                96
# 7                        95                                95
# 8                        88                                88
# 9                       100                               100
# 10                       87                                87
# 11                       82                                82
# 13                       93                                93
#
#     HouseholdIncome  FundingPerStudent DropoutPercentageRate  \
# ...

# %%
print(df.isnull().sum())
# Out:
# GraduationPercentageRate             0
# OrgininalGraduationPercentageRate    0
# HouseholdIncome                      0
# FundingPerStudent                    0
# DropoutPercentageRate                0
# Percentage of Minority Students      0
# dtype: int64

# %%
df.to_csv(r"C:\Users\Minet\Documents\Repositories\Dev10_Final_Project\Datasets\MLModelDatasetPowerBI2.csv")
