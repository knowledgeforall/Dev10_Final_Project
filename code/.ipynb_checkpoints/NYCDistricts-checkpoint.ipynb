# %%
import pandas as pd

# %% [markdown]
# Import Budget Information for the 32 districts in NYC

# %%
nycdistricts = pd.read_csv('../Datasets/NYCSchoolDistricts.csv')
nycdistricts.columns
# Out:
# Index(['District', 'School Code', 'School Name', 'School Type',
#        'Weighted Register Allocation',
#        'Weighted Register Allocation If FSF Fully Funded',
#        'Weighted Register Allocation Gap to 100%', '% Funded',
#        'Foundation \r\n(not included in the funding %)',
#        'Collective Bargaining for School Based Staff (not included in the funding %)',
#        'Total FSF Allocation Including Foundation and Collective Bargaining Costs',
#        'Total FSF Allocation at 100% Including Foundation & Adjusted for Collective Bargaining Costs',
#        'Total FSF Allocation Gap to 100% Including Foundation & Adjusted for Collective Bargaining Costs',
#        'Total Budget Allocation', 'FSF as % of Total Budget Allocation',
#        'Non-FSF Budget Allocations'],
#       dtype='object')

# %%
#Isolate two columns needed
nycdistrictsinfo = nycdistricts[['District','Total Budget Allocation']]
nycdistrictsinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1608 entries, 0 to 1607
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   District                 1608 non-null   object
#  1   Total Budget Allocation  1608 non-null   object
# dtypes: object(2)
# memory usage: 25.2+ KB

# %%
nycdistrictsinfo.head()
# Out:
#   District Total Budget Allocation
# 0       01           $   4,966,456
# 1       01           $   7,977,207
# 2       01           $   9,114,056
# 3       01           $   7,329,616
# 4       01           $   5,840,771

# %%
#Add needed information to empty list

totalbudget = []

for i in nycdistrictsinfo['Total Budget Allocation']:
    totalbudget.append(i)

# %%
#Clean up data

totalbudget = [x.replace('$', '') for x in totalbudget]
totalbudget = [x.replace(' ', '') for x in totalbudget]
totalbudget = [x.replace(',', '') for x in totalbudget]

nycdistrictsinfo['Total Budget Allocation'] = totalbudget
nycdistrictsinfo.head()
# Out:
# C:\Users\Yiqing Guo\AppData\Local\Temp\ipykernel_18840\308010859.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nycdistrictsinfo['Total Budget Allocation'] = totalbudget
#   District Total Budget Allocation
# 0       01                 4966456
# 1       01                 7977207
# 2       01                 9114056
# 3       01                 7329616
# 4       01                 5840771

# %%
#Change column to numeric

nycdistrictsinfo['Total Budget Allocation'] = pd.to_numeric(nycdistrictsinfo['Total Budget Allocation'])
# Out:
# C:\Users\Yiqing Guo\AppData\Local\Temp\ipykernel_18840\1943056143.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nycdistrictsinfo['Total Budget Allocation'] = pd.to_numeric(nycdistrictsinfo['Total Budget Allocation'])

# %%
#Group by district to get total funding per district

districtbudget = nycdistrictsinfo.groupby('District').sum()
districtbudgetlist = []
for i in districtbudget['Total Budget Allocation']:
    districtbudgetlist.append(i)
print(districtbudgetlist)
# Out:
# [200591725, 946172546, 352123037, 246147021, 216954795, 391676770, 360439960, 493947174, 616340058, 914314503, 627403714, 391938125, 324995162, 319761813, 539612949, 135184883, 366965145, 253044431, 391242220, 783381385, 575292720, 535629979, 178523951, 887265884, 570229915, 437105316, 717548919, 576686058, 400675834, 591321152, 1096239269, 206636804, 154477899, 1936630130, 17736501242]

# %%
#Read in districtinfo csv

districtinfo = pd.read_csv('../Datasets/PreliminaryDistrictDataWITHMEDIANINCOME2.csv')
districtinfo.head()
# Out:
#    Unnamed: 0                 DistrictName GraduationPercentageRate  \
# 0           0                  ADDISON CSD                       90
# 1           1               ADIRONDACK CSD                       92
# 2           2                    AFTON CSD                       83
# 3           3                    AKRON CSD                       95
# 4           4  ALBANY CITY SCHOOL DISTRICT                       71
#
#   DropoutPercentageRate  FundingPerStudent  TotalEnrolled  MalesEnrolled  \
# 0                     3           23833.02            976            503
# 1                     5           14013.61           1145            575
# 2                    10           24128.02            507            262
# 3                     3           17552.56           1334            667
# 4                    12           22382.65           8610           4444
#
#    FemalesEnrolled  Percentage of Minority Students  HouseholdIncome
# 0              473                              3.2          71205.0
# 1              570                              1.7          73795.0
# 2              245                              8.9          64191.0
# 3              667                             17.5          93480.0
# 4             4166                             80.2          80885.0

# %%
#Find what index the NYC Districts are located 

districtinfo[districtinfo['DistrictName'].str.contains('NYC')]
# Out:
#      Unnamed: 0                       DistrictName GraduationPercentageRate  \
# 441         441      NYC GEOG DIST # 1 - MANHATTAN                       68
# 442         442      NYC GEOG DIST # 2 - MANHATTAN                       81
# 443         443      NYC GEOG DIST # 3 - MANHATTAN                       81
# 444         444      NYC GEOG DIST # 4 - MANHATTAN                       85
# 445         445      NYC GEOG DIST # 5 - MANHATTAN                       74
# 446         446      NYC GEOG DIST # 6 - MANHATTAN                       75
# 447         447          NYC GEOG DIST # 7 - BRONX                       69
# 448         448          NYC GEOG DIST # 8 - BRONX                       66
# 449         449          NYC GEOG DIST # 9 - BRONX                       74
# 450         450          NYC GEOG DIST #10 - BRONX                       80
# 451         451          NYC GEOG DIST #11 - BRONX                       75
# 452         452          NYC GEOG DIST #12 - BRONX                       63
# 453         453       NYC GEOG DIST #13 - BROOKLYN                       90
# 454         454       NYC GEOG DIST #14 - BROOKLYN                       82
# 455         455       NYC GEOG DIST #15 - BROOKLYN                       71
# 456         456       NYC GEOG DIST #16 - BROOKLYN                       60
# 457         457       NYC GEOG DIST #17 - BROOKLYN                       74
# 458         458       NYC GEOG DIST #18 - BROOKLYN                       67
# 459         459       NYC GEOG DIST #19 - BROOKLYN                       79
# 460         460       NYC GEOG DIST #20 - BROOKLYN                       76
# 461         461       NYC GEOG DIST #21 - BROOKLYN                       77
# 462         462       NYC GEOG DIST #22 - BROOKLYN                       85
# 463         463       NYC GEOG DIST #23 - BROOKLYN                       52
# 464         464         NYC GEOG DIST #24 - QUEENS                       80
# 465         465         NYC GEOG DIST #25 - QUEENS                       76
# 466         466         NYC GEOG DIST #26 - QUEENS                       92
# 467         467         NYC GEOG DIST #27 - QUEENS                       76
# 468         468         NYC GEOG DIST #28 - QUEENS                       84
# 469         469         NYC GEOG DIST #29 - QUEENS                       77
# 470         470         NYC GEOG DIST #30 - QUEENS                       86
# 471         471  NYC GEOG DIST #31 - STATEN ISLAND                       84
# 472         472       NYC GEOG DIST #32 - BROOKLYN                       75
# 473         473         NYC SPEC SCHOOLS - DIST 75                        —
#
#     DropoutPercentageRate  FundingPerStudent  TotalEnrolled  MalesEnrolled  \
# 441                     8                NaN          10473           5481
# 442                     5                NaN          59568          28456
# 443                     3                NaN          21132           9599
# 444                     4                NaN          11510           5594
# 445                     5                NaN           9332           4954
# 446                     5                NaN          19124           9709
# 447                     9                NaN          16318           8639
# 448                    13                NaN          24613          12660
# 449                     9                NaN          29653          14989
# 450                     7                NaN          49381          25187
# 451                     8                NaN          35438          18643
# 452                    12                NaN          19427          10007
# 453                     2                NaN          19994          10672
# 454                     5                NaN          16583           8684
# 455                     5                NaN          29846          14881
# 456                     5                NaN           5425           2891
# 457                     6                NaN          19019           9361
# 458                     6                NaN          12417           6499
# 459                     6                NaN          19389          10230
# 460                     7                NaN          49535          25915
# 461                     6                NaN          33868          17379
# 462                     3                NaN          31931          16127
# 463                    12                NaN           7714           4315
# 464                     5                NaN          54124          28429
# 465                     5                NaN          35583          18163
# 466                     3                NaN          30802          15826
# 467                    10                NaN          40675          21347
# 468                     5                NaN          38378          19482
# 469                     6                NaN          23776          12395
# 470                     4                NaN          36697          18539
# 471                     4                NaN          57787          29605
# 472                     8                NaN           9850           5045
# 473                     —                NaN          25358          18632
#
#      FemalesEnrolled  Percentage of Minority Students  HouseholdIncome
# 441             4992                             81.6              NaN
# 442            31112                             73.4              NaN
# 443            11533                             66.5              NaN
# 444             5916                             95.0              NaN
# 445             4378                             93.6              NaN
# 446             9415                             94.4              NaN
# 447             7679                             98.5              NaN
# 448            11953                             94.4              NaN
# 449            14664                             98.7              NaN
# 450            24194                             94.1              NaN
# 451            16795                             91.1              NaN
# 452             9420                             98.6              NaN
# 453             9322                             82.8              NaN
# 454             7899                             85.1              NaN
# 455            14965                             69.9              NaN
# 456             2534                             97.3              NaN
# 457             9658                             96.9              NaN
# 458             5918                             96.6              NaN
# 459             9159                             97.9              NaN
# 460            23620                             75.5              NaN
# 461            16489                             67.6              NaN
# 462            15804                             67.4              NaN
# 463             3399                             98.7              NaN
# 464            25695                             86.8              NaN
# 465            17420                             88.7              NaN
# 466            14976                             84.7              NaN
# 467            19328                             90.0              NaN
# 468            18896                             84.4              NaN
# 469            11381                             98.2              NaN
# 470            18158                             83.4              NaN
# 471            28182                             55.6              NaN
# 472             4805                             97.6              NaN
# 473             6726                             87.3              NaN

# %%
#Get the enrollment values in a list

NYCTotalEnrolled = []
for i in districtinfo['TotalEnrolled'].loc[441:473]:
    NYCTotalEnrolled.append(i)
print(NYCTotalEnrolled)
# Out:
# [10473, 59568, 21132, 11510, 9332, 19124, 16318, 24613, 29653, 49381, 35438, 19427, 19994, 16583, 29846, 5425, 19019, 12417, 19389, 49535, 33868, 31931, 7714, 54124, 35583, 30802, 40675, 38378, 23776, 36697, 57787, 9850, 25358]

# %%
#Divide both lists to get funding per student per district

districtfundingperchild = [i / j for i, j in zip(districtbudgetlist, NYCTotalEnrolled)]
districtfundingperchild = [round(num,2) for num in districtfundingperchild]
print(districtfundingperchild)
# Out:
# [19153.22, 15883.91, 16663.02, 21385.49, 23248.48, 20480.9, 22088.49, 20068.55, 20785.08, 18515.51, 17704.26, 20174.92, 16254.63, 19282.51, 18079.91, 24918.87, 19294.66, 20378.87, 20178.57, 15814.7, 16986.32, 16774.61, 23142.85, 16393.21, 16025.35, 14190.81, 17641.03, 15026.48, 16852.11, 16113.61, 18970.34, 20978.36, 6091.88]

# %%
#Update column values 

one = 0

for i in range (441,474):

    districtinfo.at[i, 'FundingPerStudent'] = districtfundingperchild[one]

    one = one + 1

# %%
#Confirm column was updated
districtinfo[districtinfo['DistrictName'].str.contains('NYC')]
# Out:
#      Unnamed: 0                       DistrictName GraduationPercentageRate  \
# 441         441      NYC GEOG DIST # 1 - MANHATTAN                       68
# 442         442      NYC GEOG DIST # 2 - MANHATTAN                       81
# 443         443      NYC GEOG DIST # 3 - MANHATTAN                       81
# 444         444      NYC GEOG DIST # 4 - MANHATTAN                       85
# 445         445      NYC GEOG DIST # 5 - MANHATTAN                       74
# 446         446      NYC GEOG DIST # 6 - MANHATTAN                       75
# 447         447          NYC GEOG DIST # 7 - BRONX                       69
# 448         448          NYC GEOG DIST # 8 - BRONX                       66
# 449         449          NYC GEOG DIST # 9 - BRONX                       74
# 450         450          NYC GEOG DIST #10 - BRONX                       80
# 451         451          NYC GEOG DIST #11 - BRONX                       75
# 452         452          NYC GEOG DIST #12 - BRONX                       63
# 453         453       NYC GEOG DIST #13 - BROOKLYN                       90
# 454         454       NYC GEOG DIST #14 - BROOKLYN                       82
# 455         455       NYC GEOG DIST #15 - BROOKLYN                       71
# 456         456       NYC GEOG DIST #16 - BROOKLYN                       60
# 457         457       NYC GEOG DIST #17 - BROOKLYN                       74
# 458         458       NYC GEOG DIST #18 - BROOKLYN                       67
# 459         459       NYC GEOG DIST #19 - BROOKLYN                       79
# 460         460       NYC GEOG DIST #20 - BROOKLYN                       76
# 461         461       NYC GEOG DIST #21 - BROOKLYN                       77
# 462         462       NYC GEOG DIST #22 - BROOKLYN                       85
# 463         463       NYC GEOG DIST #23 - BROOKLYN                       52
# 464         464         NYC GEOG DIST #24 - QUEENS                       80
# 465         465         NYC GEOG DIST #25 - QUEENS                       76
# 466         466         NYC GEOG DIST #26 - QUEENS                       92
# 467         467         NYC GEOG DIST #27 - QUEENS                       76
# 468         468         NYC GEOG DIST #28 - QUEENS                       84
# 469         469         NYC GEOG DIST #29 - QUEENS                       77
# 470         470         NYC GEOG DIST #30 - QUEENS                       86
# 471         471  NYC GEOG DIST #31 - STATEN ISLAND                       84
# 472         472       NYC GEOG DIST #32 - BROOKLYN                       75
# 473         473         NYC SPEC SCHOOLS - DIST 75                        —
#
#     DropoutPercentageRate  FundingPerStudent  TotalEnrolled  MalesEnrolled  \
# 441                     8           19153.22          10473           5481
# 442                     5           15883.91          59568          28456
# 443                     3           16663.02          21132           9599
# 444                     4           21385.49          11510           5594
# 445                     5           23248.48           9332           4954
# 446                     5           20480.90          19124           9709
# 447                     9           22088.49          16318           8639
# 448                    13           20068.55          24613          12660
# 449                     9           20785.08          29653          14989
# 450                     7           18515.51          49381          25187
# 451                     8           17704.26          35438          18643
# 452                    12           20174.92          19427          10007
# 453                     2           16254.63          19994          10672
# 454                     5           19282.51          16583           8684
# 455                     5           18079.91          29846          14881
# 456                     5           24918.87           5425           2891
# 457                     6           19294.66          19019           9361
# 458                     6           20378.87          12417           6499
# 459                     6           20178.57          19389          10230
# 460                     7           15814.70          49535          25915
# 461                     6           16986.32          33868          17379
# 462                     3           16774.61          31931          16127
# 463                    12           23142.85           7714           4315
# 464                     5           16393.21          54124          28429
# 465                     5           16025.35          35583          18163
# 466                     3           14190.81          30802          15826
# 467                    10           17641.03          40675          21347
# 468                     5           15026.48          38378          19482
# 469                     6           16852.11          23776          12395
# 470                     4           16113.61          36697          18539
# 471                     4           18970.34          57787          29605
# 472                     8           20978.36           9850           5045
# 473                     —            6091.88          25358          18632
#
#      FemalesEnrolled  Percentage of Minority Students  HouseholdIncome
# 441             4992                             81.6              NaN
# 442            31112                             73.4              NaN
# 443            11533                             66.5              NaN
# 444             5916                             95.0              NaN
# 445             4378                             93.6              NaN
# 446             9415                             94.4              NaN
# 447             7679                             98.5              NaN
# 448            11953                             94.4              NaN
# 449            14664                             98.7              NaN
# 450            24194                             94.1              NaN
# 451            16795                             91.1              NaN
# 452             9420                             98.6              NaN
# 453             9322                             82.8              NaN
# 454             7899                             85.1              NaN
# 455            14965                             69.9              NaN
# 456             2534                             97.3              NaN
# 457             9658                             96.9              NaN
# 458             5918                             96.6              NaN
# 459             9159                             97.9              NaN
# 460            23620                             75.5              NaN
# 461            16489                             67.6              NaN
# 462            15804                             67.4              NaN
# 463             3399                             98.7              NaN
# 464            25695                             86.8              NaN
# 465            17420                             88.7              NaN
# 466            14976                             84.7              NaN
# 467            19328                             90.0              NaN
# 468            18896                             84.4              NaN
# 469            11381                             98.2              NaN
# 470            18158                             83.4              NaN
# 471            28182                             55.6              NaN
# 472             4805                             97.6              NaN
# 473             6726                             87.3              NaN

# %%
districtinfo[districtinfo['HouseholdIncome'].isna()]
# Out:
#      Unnamed: 0                          DistrictName  \
# 43           43              BELLEVILLE-HENDERSON CSD
# 45           45  BELLMORE-MERRICK CENTRAL HS DISTRICT
# 47           47                        BERKSHIRE UFSD
# 56           56                     BOQUET VALLEY CSD
# 99           99    CENTRAL VALLEY CSD AT ILION-MOHAWK
# ..          ...                                   ...
# 654         654                 VALLEY STREAM 13 UFSD
# 655         655                 VALLEY STREAM 24 UFSD
# 656         656                 VALLEY STREAM 30 UFSD
# 657         657     VALLEY STREAM CENTRAL HS DISTRICT
# 658         658      VAN HORNESVILLE-OWEN D YOUNG CSD
#
#     GraduationPercentageRate DropoutPercentageRate  FundingPerStudent  \
# 43                        92                     0           16968.41
# 45                        97                     0           25413.48
# 47                         —                     —                NaN
# 56                        92                     8           29438.51
# 99                        87                     5           15522.11
# ..                       ...                   ...                ...
# 654                        —                     —           21831.30
# 655                        —                     —           23989.49
# 656                        —                     —           21680.41
# 657                       93                     2           22335.67
# 658                       91                     5           23917.91
#
#      TotalEnrolled  MalesEnrolled  FemalesEnrolled  \
# 43             463            240              223
# 45            5272           2672             2600
# 47              83             72               11
# 56             410            220              190
# 99            2082           1025             1057
# ..             ...            ...              ...
# 654           1963           1049              914
# 655           1097            560              537
# 656           1464            745              719
# 657           4542           2315             2227
# 658            181             85               96
#
#      Percentage of Minority Students  HouseholdIncome
# 43                               8.4              NaN
# 45                              21.7              NaN
# 47                              61.4              NaN
# 56                               2.4              NaN
# 99                               9.4              NaN
# ..                               ...              ...
# 654                             76.4              NaN
# 655                             82.2              NaN
# 656                             95.3              NaN
# 657                             83.6              NaN
# 658                              3.3              NaN
#
# [72 rows x 10 columns]

# %%
districtinfo.to_csv('../Datasets/PreliminaryDistrictDataNYCDistrictsFunding3.csv')

# %%
nycdistricts = pd.read_csv('../Datasets/medianincomenyc.csv')
nycdistricts.head()
# Out:
#                     DistrictName   MedianIncome
# 0  NYC GEOG DIST # 1 - MANHATTAN   77936.000000
# 1  NYC GEOG DIST # 2 - MANHATTAN  127275.961538
# 2  NYC GEOG DIST # 3 - MANHATTAN  104303.666667
# 3  NYC GEOG DIST # 4 - MANHATTAN   31104.500000
# 4  NYC GEOG DIST # 5 - MANHATTAN   50067.000000

# %%
#Read in districtinfo csv

districtinfo = pd.read_csv('../Datasets/PreliminaryDistrictDataNYCDistrictsFunding3.csv')

# %%
#Find what index the NYC Districts are located 

districtinfo[districtinfo['DistrictName'].str.contains('NYC')]
# Out:
#      Unnamed: 0.1  Unnamed: 0                       DistrictName  \
# 441           441         441      NYC GEOG DIST # 1 - MANHATTAN
# 442           442         442      NYC GEOG DIST # 2 - MANHATTAN
# 443           443         443      NYC GEOG DIST # 3 - MANHATTAN
# 444           444         444      NYC GEOG DIST # 4 - MANHATTAN
# 445           445         445      NYC GEOG DIST # 5 - MANHATTAN
# 446           446         446      NYC GEOG DIST # 6 - MANHATTAN
# 447           447         447          NYC GEOG DIST # 7 - BRONX
# 448           448         448          NYC GEOG DIST # 8 - BRONX
# 449           449         449          NYC GEOG DIST # 9 - BRONX
# 450           450         450          NYC GEOG DIST #10 - BRONX
# 451           451         451          NYC GEOG DIST #11 - BRONX
# 452           452         452          NYC GEOG DIST #12 - BRONX
# 453           453         453       NYC GEOG DIST #13 - BROOKLYN
# 454           454         454       NYC GEOG DIST #14 - BROOKLYN
# 455           455         455       NYC GEOG DIST #15 - BROOKLYN
# 456           456         456       NYC GEOG DIST #16 - BROOKLYN
# 457           457         457       NYC GEOG DIST #17 - BROOKLYN
# 458           458         458       NYC GEOG DIST #18 - BROOKLYN
# 459           459         459       NYC GEOG DIST #19 - BROOKLYN
# 460           460         460       NYC GEOG DIST #20 - BROOKLYN
# 461           461         461       NYC GEOG DIST #21 - BROOKLYN
# 462           462         462       NYC GEOG DIST #22 - BROOKLYN
# 463           463         463       NYC GEOG DIST #23 - BROOKLYN
# 464           464         464         NYC GEOG DIST #24 - QUEENS
# 465           465         465         NYC GEOG DIST #25 - QUEENS
# 466           466         466         NYC GEOG DIST #26 - QUEENS
# 467           467         467         NYC GEOG DIST #27 - QUEENS
# 468           468         468         NYC GEOG DIST #28 - QUEENS
# 469           469         469         NYC GEOG DIST #29 - QUEENS
# 470           470         470         NYC GEOG DIST #30 - QUEENS
# 471           471         471  NYC GEOG DIST #31 - STATEN ISLAND
# 472           472         472       NYC GEOG DIST #32 - BROOKLYN
# 473           473         473         NYC SPEC SCHOOLS - DIST 75
#
#     GraduationPercentageRate DropoutPercentageRate  FundingPerStudent  \
# 441                       68                     8           19153.22
# 442                       81                     5           15883.91
# 443                       81                     3           16663.02
# 444                       85                     4           21385.49
# 445                       74                     5           23248.48
# 446                       75                     5           20480.90
# 447                       69                     9           22088.49
# 448                       66                    13           20068.55
# 449                       74                     9           20785.08
# 450                       80                     7           18515.51
# 451                       75                     8           17704.26
# 452                       63                    12           20174.92
# 453                       90                     2           16254.63
# 454                       82                     5           19282.51
# 455                       71                     5           18079.91
# 456                       60                     5           24918.87
# 457                       74                     6           19294.66
# 458                       67                     6           20378.87
# 459                       79                     6           20178.57
# 460                       76                     7           15814.70
# 461                       77                     6           16986.32
# 462                       85                     3           16774.61
# 463                       52                    12           23142.85
# 464                       80                     5           16393.21
# 465                       76                     5           16025.35
# 466                       92                     3           14190.81
# 467                       76                    10           17641.03
# 468                       84                     5           15026.48
# 469                       77                     6           16852.11
# 470                       86                     4           16113.61
# 471                       84                     4           18970.34
# 472                       75                     8           20978.36
# 473                        —                     —            6091.88
#
#      TotalEnrolled  MalesEnrolled  FemalesEnrolled  \
# 441          10473           5481             4992
# 442          59568          28456            31112
# 443          21132           9599            11533
# 444          11510           5594             5916
# 445           9332           4954             4378
# 446          19124           9709             9415
# 447          16318           8639             7679
# 448          24613          12660            11953
# 449          29653          14989            14664
# 450          49381          25187            24194
# 451          35438          18643            16795
# 452          19427          10007             9420
# 453          19994          10672             9322
# 454          16583           8684             7899
# 455          29846          14881            14965
# 456           5425           2891             2534
# 457          19019           9361             9658
# 458          12417           6499             5918
# 459          19389          10230             9159
# 460          49535          25915            23620
# 461          33868          17379            16489
# 462          31931          16127            15804
# 463           7714           4315             3399
# 464          54124          28429            25695
# 465          35583          18163            17420
# 466          30802          15826            14976
# 467          40675          21347            19328
# 468          38378          19482            18896
# 469          23776          12395            11381
# 470          36697          18539            18158
# 471          57787          29605            28182
# 472           9850           5045             4805
# 473          25358          18632             6726
#
#      Percentage of Minority Students  HouseholdIncome
# 441                             81.6              NaN
# 442                             73.4              NaN
# 443                             66.5              NaN
# 444                             95.0              NaN
# 445                             93.6              NaN
# 446                             94.4              NaN
# 447                             98.5              NaN
# 448                             94.4              NaN
# 449                             98.7              NaN
# 450                             94.1              NaN
# 451                             91.1              NaN
# 452                             98.6              NaN
# 453                             82.8              NaN
# 454                             85.1              NaN
# 455                             69.9              NaN
# 456                             97.3              NaN
# 457                             96.9              NaN
# 458                             96.6              NaN
# 459                             97.9              NaN
# 460                             75.5              NaN
# 461                             67.6              NaN
# 462                             67.4              NaN
# 463                             98.7              NaN
# 464                             86.8              NaN
# 465                             88.7              NaN
# 466                             84.7              NaN
# 467                             90.0              NaN
# 468                             84.4              NaN
# 469                             98.2              NaN
# 470                             83.4              NaN
# 471                             55.6              NaN
# 472                             97.6              NaN
# 473                             87.3              NaN

# %%
#Update column values 
for i in range(0,len(nycdistricts)):
    name = nycdistricts.iloc[i].DistrictName
    householdincome = nycdistricts.iloc[i].MedianIncome
    districtindex = districtinfo[districtinfo['DistrictName'] == name].index[0]
    districtinfo.at[districtindex,'HouseholdIncome'] = householdincome

# %%
districtinfo.to_csv('../Datasets/PreliminaryDistrictDataNYCDistrictsIncome4.csv')
