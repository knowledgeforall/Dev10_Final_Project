# %% [markdown]
# Group 3 SQL Server: capstone-group3
#
# Group 3 Raw Data Blob: capstone-group3-raw
#
# Group 3 Consumer Data Blob: capstone-group3-consumed
#
# Group 3 Data Factory: datafactory-group3
#
# Data Factory to Data Brick Access Token: dapic9756871672f25cdac8c8b7a56464f7b-2
